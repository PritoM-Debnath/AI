# %% [markdown]
# ![map.JPG](attachment:map.JPG)

# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75,'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %%
task_map={
    'S':{'G':12,'A':1},
    'A':{'B':3,'C':1},
    'B':{'D':3},
    'C':{'D':1,'G':2},
    'G':{},
    'D':{'G':1},
}

# %%
romanian_map['Arad']
# Out:
# {'Sibiu': 140, 'Timisoara': 118, 'Zerind': 75}

# %%
list(romanian_map['Arad'].keys())
# Out:
# ['Sibiu', 'Zerind', 'Timisoara']

# %%
romanian_map['Arad']['Zerind']
# Out:
# 75

# %%
romanian_map['Zerind']['Arad']
# Out:
# 75

# %%
list(romanian_map.keys())
# Out:
# ['Arad',
#  'Zerind',
#  'Oradea',
#  'Sibiu',
#  'Timisoara',
#  'Lugoj',
#  'Mehadia',
#  'Drobeta',
#  'Craiova',
#  'Rimnicu',
#  'Fagaras',
#  'Pitesti',
#  'Bucharest',
#  'Giurgiu',
#  'Urziceni',
#  'Hirsova',
#  'Eforie',
#  'Vaslui',
#  'Iasi',
#  'Neamt']

# %% [markdown]
# # BFS

# %% [markdown]
# <p style="text-align: justify">Reached is a set of states which has been generated, because once we’ve reached a state, Early goal test we can never find a better path to the state. That also means we can do an early goal test, Late goal test checking whether a node is a solution as soon as it is generated, rather than the late goal test that best-first search uses, waiting until a node is popped off the queue.</p>

# %%
def bfs(startingNode, destinationNode,G):
    reached = [] # to store reached (generated) nodes
    expand_sequence = [] # to store the order of nodes expanded
    frontier = []

    snode = {'City':startingNode,'Path cost':0, 'Path':[startingNode]}
    frontier.append(snode)    # insert the starting node
    reached.append(startingNode)
    
    while len(frontier) > 0:
        print(frontier)
        unode  = frontier.pop(0)     # selceting the node to expand
        u = unode['City']
        expand_sequence.append(u)
        print(u + " expanding..")
        # expand u
        
        for v in G[u].keys():
            if v not in reached: # process if v is not reached (generated) yet                
                print(v+" generated.")
                cost = unode['Path cost'] + G[u][v] 
                path =  unode['Path']+ [v]
                vnode = {'City': v,'Path cost': cost,'Path': path}
                frontier.append(vnode)# store the new child node in the frontier
                reached.append(v)
                # goal test
                if v == destinationNode:
                    #print(vnode)
                    print(expand_sequence)
                    return vnode # breaking from while
    print('Failed')

# %%
bfs('S', 'G',task_map)
# Out:
# [{'City': 'S', 'Path cost': 0, 'Path': ['S']}]
# S expanding..
# G generated.
# ['S']
# {'City': 'G', 'Path': ['S', 'G'], 'Path cost': 12}

# %%
bfs('Arad', 'Bucharest',romanian_map) # change the soure and destination
# Out:
# [{'City': 'Arad', 'Path cost': 0, 'Path': ['Arad']}]
# Arad expanding..
# Timisoara generated.
# Sibiu generated.
# Zerind generated.
# [{'City': 'Timisoara', 'Path cost': 118, 'Path': ['Arad', 'Timisoara']}, {'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}]
# Timisoara expanding..
# Lugoj generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}]
# Sibiu expanding..
# Oradea generated.
# Fagaras generated.
# Rimnicu generated.
# [{'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}, {'City': 'Oradea', 'Path cost': 291, 'Path': ['Arad', 'Sibiu', 'Oradea']}, {'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}]
# Zerind expanding..
# [{'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}, {'City': 'Oradea', 'Path cost': 291, 'Path': ['Arad', 'Sibiu', 'Oradea']}, {'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}]
# Lugoj expanding..
# Mehadia generated.
# [{'City': 'Oradea', 'Path cost': 291, 'Path': ['Arad', 'Sibiu', 'Oradea']}, {'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}, {'City': 'Mehadia', 'Path cost': 299, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']}]
# Oradea expanding..
# [{'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}, {'City': 'Mehadia', 'Path cost': 299, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']}]
# Fagaras expanding..
# Bucharest generated.
# ['Arad', 'Timisoara', 'Sibiu', 'Zerind', 'Lugoj', 'Oradea', 'Fagaras']
# {'City': 'Bucharest',
#  'Path': ['Arad', 'Sibiu', 'Fagaras', 'Bucharest'],
#  'Path cost': 450}

# %% [markdown]
# # DFS
# Implement DFS using stack,
# Implement stack using list (append and pop)

# %%
# code dfs here
def dfs(startingNode, destinationNode,G):
    reached = [] # to store reached (generated) nodes
    expand_sequence = [] # to store the order of nodes expanded
    frontier = []

    snode = {'City':startingNode,'Path cost':0, 'Path':[startingNode]}
    frontier.append(snode)    # insert the starting node
    reached.append(startingNode)
    
    while len(frontier) > 0:
        print(frontier)
        unode  = frontier.pop(-1)     # selceting the node to expand
        u = unode['City']
        expand_sequence.append(u)
        print(u + " expanding..")
        # expand u
        # goal test
        if u == destinationNode:
          #print(vnode)
          print(expand_sequence)
          return unode # breaking from while
        
        for v in G[u].keys():
            if v not in expand_sequence: # process if v is not reached (generated) yet                
                print(v+" generated.")
                cost = unode['Path cost'] + G[u][v] 
                path =  unode['Path']+ [v]
                vnode = {'City': v,'Path cost': cost,'Path': path}
                frontier.append(vnode)# store the new child node in the frontier
                reached.append(v)
                
    print('Failed')

# %%
dfs('Arad', 'Bucharest',romanian_map)
# Out:
# [{'City': 'Arad', 'Path cost': 0, 'Path': ['Arad']}]
# Arad expanding..
# Sibiu generated.
# Zerind generated.
# Timisoara generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Timisoara', 'Path cost': 118, 'Path': ['Arad', 'Timisoara']}]
# Timisoara expanding..
# Lugoj generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}]
# Lugoj expanding..
# Mehadia generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Mehadia', 'Path cost': 299, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']}]
# Mehadia expanding..
# Drobeta generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Drobeta', 'Path cost': 374, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']}]
# Drobeta expanding..
# Craiova generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Craiova', 'Path cost': 494, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova']}]
# Craiova expanding..
# Rimnicu generated.
# Pitesti generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Rimnicu', 'Path cost': 640, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu']}, {'City': 'Pitesti', 'Path cost': 632, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti']}]
# Pitesti expanding..
# Bucharest generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Rimnicu', 'Path cost': 640, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu']}, {'City': 'Bucharest', 'Path cost': 733, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']}]
# Bucharest expanding..
# ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# {'City': 'Bucharest',
#  'Path': ['Arad',
#   'Timisoara',
#   'Lugoj',
#   'Mehadia',
#   'Drobeta',
#   'Craiova',
#   'Pitesti',
#   'Bucharest'],
#  'Path cost': 733}

# %%
dfs('S', 'G',task_map)
# Out:
# [{'City': 'S', 'Path cost': 0, 'Path': ['S']}]
# S expanding..
# G generated.
# A generated.
# [{'City': 'G', 'Path cost': 12, 'Path': ['S', 'G']}, {'City': 'A', 'Path cost': 1, 'Path': ['S', 'A']}]
# A expanding..
# B generated.
# C generated.
# [{'City': 'G', 'Path cost': 12, 'Path': ['S', 'G']}, {'City': 'B', 'Path cost': 4, 'Path': ['S', 'A', 'B']}, {'City': 'C', 'Path cost': 2, 'Path': ['S', 'A', 'C']}]
# C expanding..
# D generated.
# G generated.
# [{'City': 'G', 'Path cost': 12, 'Path': ['S', 'G']}, {'City': 'B', 'Path cost': 4, 'Path': ['S', 'A', 'B']}, {'City': 'D', 'Path cost': 3, 'Path': ['S', 'A', 'C', 'D']}, {'City': 'G', 'Path cost': 4, 'Path': ['S', 'A', 'C', 'G']}]
# G expanding..
# ['S', 'A', 'C', 'G']
# {'City': 'G', 'Path': ['S', 'A', 'C', 'G'], 'Path cost': 4}
